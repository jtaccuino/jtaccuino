// %%
addDependency("org.knowm.xchart:xchart:3.5.2")

// %%
import org.knowm.xchart.*;

double[] xData = new double[] { 0.0, 1.0, 2.0 };
double[] yData = new double[] { 2.0, 1.0, 0.0 };

// %%
display(xData)

// %%
var chart = QuickChart.getChart("Sample Chart", "X", "Y", "y(x)", xData, yData);

// %%
display(BitmapEncoder.getBufferedImage(chart))
