// %%
var props = System.getProperties();
var javaPropNames = props.stringPropertyNames().stream().filter(s->s.contains("java")).toList();

// %%
display(javaPropNames);

// %%
var propMap = props.entrySet();

// %%
display(propMap)
