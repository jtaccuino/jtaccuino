// %% [markdown]
// ## Plotting

// %% [markdown]
// Enable the on demand extension for simple plotting with FXCharts

// %%
use(JTExtension.FX_CHARTS_EXTENSION)

// %% [markdown]
// Define a simple graph, based on a function, and a range for both axis

// %%
var sin = plotFx(Math::sin, -10, +10, 0.1, "x", "y", "sin(x)");

// %%
display(sin);

// %%
var cos = plotFx(Math::cos, -10, +10, 0.1, "x", "y", "cos(x)");

// %%
display(cos);

// %%
var sincos = plotFx(x->Math.sin(x)*Math.cos(x),1 -10, +10, 0.1, "x", "y", "cos(x)");

// %%
display(sincos)
